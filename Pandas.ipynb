# %% [raw]
# 1)What is pandas
# ## def: pandas is a python library used for data cleaning,analysis and manipulation
# ## works like excel but faster
# ## helps load clean, fliter, analyze, data
# ## data science, machine leaning, finance, analytics, and automating data tasks

# %% [raw]
# 2)importing pandas

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.3'

# %% [raw]
# 3)pandas data structures
# series: one dimensional column
# dataframe: table with rows and columns

# %%
s = pd.Series([10,20,30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({
    "name":["pavan","vinay"],
    "age":[25,23]
    })
df
# Out:
#     name  age
# 0  pavan   25
# 1  vinay   23

# %% [raw]
# 4)reading csv

# %%
df = pd.read_csv('data1.csv')
df
# Out:
#          date       city  temperature  humidity condition
# 0  01-01-2025   hyderbad           32        32     sunny
# 1  02-01-2025   hyderbad           30        29      cold
# 2  03-01-2025   hyderbad           33        27     sunny
# 3  04-01-2025   hyderbad           34        29    cloudy
# 4  05-01-2025   hyderbad           33        33     rainy
# 5  06-01-2025  bangalore           28        32     rainy
# 6  07-01-2025  bangalore           32        29     sunny
# 7  08-01-2025  bangalore           29        29    cloudy
# 8  09-01-2025  bangalore           31        31     rainy
# 9  10-01-2025  bangalore           28        32    sunnyu

# %% [raw]
# writing the data into files

# %%
df.to_csv('data1.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.to_csv('data1.csv',index=False)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
df

# %% [raw]
# Exlploring data

# %%
df.head()
# Out:
#          date      city  temperature  humidity condition
# 0  01-01-2025  hyderbad           32        32     sunny
# 1  02-01-2025  hyderbad           30        29      cold
# 2  03-01-2025  hyderbad           33        27     sunny
# 3  04-01-2025  hyderbad           34        29    cloudy
# 4  05-01-2025  hyderbad           33        33     rainy

# %%
df.tail()
# Out:
#          date       city  temperature  humidity condition
# 5  06-01-2025  bangalore           28        32     rainy
# 6  07-01-2025  bangalore           32        29     sunny
# 7  08-01-2025  bangalore           29        29    cloudy
# 8  09-01-2025  bangalore           31        31     rainy
# 9  10-01-2025  bangalore           28        32    sunnyu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         10 non-null     object
#  1   city         10 non-null     object
#  2   temperature  10 non-null     int64
#  3   humidity     10 non-null     int64
#  4   condition    10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df['date'] [df['condition']=='rainy']
# Out:
# 4    05-01-2025
# 5    06-01-2025
# 8    09-01-2025
# Name: date, dtype: object

# %%
df[2:5]
# Out:
#          date      city  temperature  humidity condition
# 2  03-01-2025  hyderbad           33        27     sunny
# 3  04-01-2025  hyderbad           34        29    cloudy
# 4  05-01-2025  hyderbad           33        33     rainy

# %%
df.columns
# Out:
# Index(['date', 'city', 'temperature', 'humidity', 'condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.dtypes
# Out:
# date           object
# city           object
# temperature     int64
# humidity        int64
# condition      object
# dtype: object

# %%
df.date
# Out:
# 0    01-01-2025
# 1    02-01-2025
# 2    03-01-2025
# 3    04-01-2025
# 4    05-01-2025
# 5    06-01-2025
# 6    07-01-2025
# 7    08-01-2025
# 8    09-01-2025
# 9    10-01-2025
# Name: date, dtype: object

# %%
df.city
# Out:
# 0     hyderbad
# 1     hyderbad
# 2     hyderbad
# 3     hyderbad
# 4     hyderbad
# 5    bangalore
# 6    bangalore
# 7    bangalore
# 8    bangalore
# 9    bangalore
# Name: city, dtype: object

# %%
df[['date','condition']]
# Out:
#          date condition
# 0  01-01-2025     sunny
# 1  02-01-2025      cold
# 2  03-01-2025     sunny
# 3  04-01-2025    cloudy
# 4  05-01-2025     rainy
# 5  06-01-2025     rainy
# 6  07-01-2025     sunny
# 7  08-01-2025    cloudy
# 8  09-01-2025     rainy
# 9  10-01-2025    sunnyu

# %% [markdown]
# missing value

# %%
df.isnull()
# Out:
#     date   city  temperature  humidity  condition
# 0  False  False        False     False      False
# 1  False  False        False     False      False
# 2  False  False        False     False      False
# 3  False  False        False     False      False
# 4  False  False        False     False      False
# 5  False  False        False     False      False
# 6  False  False        False     False      False
# 7  False  False        False     False      False
# 8  False  False        False     False      False
# 9  False  False        False     False      False

# %%
df = pd.DataFrame({
    "name":["pavan","vinay","deeven"],
    "age":[25,23,None]
    })
df
# Out:
#      name   age
# 0   pavan  25.0
# 1   vinay  23.0
# 2  deeven   NaN

# %%
df.isnull()
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False   True

# %%
df.isnull().sum()
# Out:
# name    0
# age     1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      name  age
# 2  deeven  NaN

# %%
df['age']=df['age'].fillna(df['age'].mean())

# %%
df
# Out:
#      name   age
# 0   pavan  25.0
# 1   vinay  23.0
# 2  deeven  24.0

# %%
df_clean=df.dropna()
df_clean
# Out:
#     name   age
# 0  pavan  25.0
# 1  vinay  23.0

# %% [raw]
# ###Duplicates

# %%
df = pd.DataFrame({
    "name":["pavan","vinay","pavan"],
    "age":[25,23,25]
    })
df
# Out:
#     name  age
# 0  pavan   25
# 1  vinay   23
# 2  pavan   25

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#     name  age
# 2  pavan   25

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     name  age
# 0  pavan   25
# 1  vinay   23
