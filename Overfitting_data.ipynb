# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("overfitting_dataset.csv")
df
# Out:
#     Study_Hours  Marks
# 0             1      5
# 1             2      1
# 2             3      8
# 3             4      2
# 4             5      9
# 5             6      3
# 6             7     10
# 7             8      4
# 8             9     11
# 9            10      5
# 10            1      6
# 11            2      2
# 12            3      9
# 13            4      3
# 14            5     10
# 15            6      4
# 16            7     11
# 17            8      5
# 18            9     12
# 19           10      6

# %%
X = df[["Study_Hours"]]
Y = df["Marks"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)
X_train
# Out:
#     Study_Hours
# 19           10
# 4             5
# 9            10
# 12            3
# 13            4
# 11            2
# 1             2
# 16            7
# 15            6
# 7             8
# 6             7
# 0             1

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# %%
Y_train_pred
# Out:
# array([7.24622716, 5.61397935, 7.24622716, 4.96108022, 5.28752979,
#        4.63463066, 4.63463066, 6.26687847, 5.94042891, 6.59332804,
#        6.26687847, 4.3081811 ])

# %%
Y_test_pred
# Out:
# array([6.9197776 , 6.59332804, 6.9197776 , 4.3081811 , 4.96108022,
#        5.61397935, 5.28752979, 5.94042891])
